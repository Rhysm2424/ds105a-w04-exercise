# %% [markdown]
# # W01 (1): The Terminal 💻
#
# ### What Is The Terminal?
#
# > It is a text based interface for the user to interact with functions and operations in a a computer
#
# > It contains a variety of unique commmands to navigate the operating system (Mac, Linux, Windows)
#
# # W01 (2): Terminal Navigation 🗺️
#
#    ***for Mac/Linux***
#
# **Navigation**
#
# | Code            | Function                            |
# |------           |----------                           |
# |cd[directory]    |Change Directory                     |
# |cd ~             |Navigate to Home Directory           |
# |cd ../../        |Navigate up Two Directories          |
# |open[file]       |Open a file                          |
# |ls               |List Files & Directories             |
# |ls ~/filepath    |List Files Without Changing Directory|
# |pwd              |Print Working Directory              |
# |mkdir[directory] |Create New Directory                 |
# |touch[file]      |Create File                          |
# |rm[file]         |Remove File                          |
# |rm -r [directory]|Remove Directory & Contents          |
#
# **File Operations**
#
# | Code                   | Function                       |
# |---                     |---                             |
# |cat[file]               |Display Contents of File        |
# |cp[source][destination] |Copy File or Directory          |
# |mv[source][destination] |Move or Rename File or Directory|
# |grep[pattern][file]     |Search for Pattern in File      |
# |chmod[permissions][file]|Change File Permissions         |
#
# **Process Management**
#
# | Code    | Function                                      |
# |---      |---                                            |
# |ps       |List Running Processes                         |
# |kill[PID]|Terminate a Process                            |
# |top      |Display System Activity and Process Information|
#
# # W01 (3): Key Points in Lecture/Class 📍
#
# > '>>>' tells you that python is active!
#
# > Single quotation marks ('') indicate a string
#
# > Strings, integers, floats and boolean are all primitive data types
#
# > A dictionary is a list of pairs with keys assigned to data - it is denoted by '{}' and key value pairs are separated by ':'
#
# ### Additional Python Commands 📜
#
#    - .replace('o', 'j') will replace all 'o' with 'j'
#
#    - .append will add an item to a list
#
#    - .split(', ') will split by a comma and a space
#
#    - += will add to a variable (-= will also take away from a variable)
#
#    - list_name[::-1] will reverse a list
#
#    - dictionary_name.update({'key_name': 'value"}) will update a dictionary under the name of a key with a new value
#
#    - from pprint import pprint - imports a new module which gives a better structure to a dictionary
#
#    - dictionary_name['key_name'][index number of value]
